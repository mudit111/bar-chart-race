# %%
import pandas as pd

# %%
# Read csv and store in a dataframe
olympics_dataset_df = pd.read_csv('https://raw.githubusercontent.com/mudit111/bar-chart-race/master/athlete_events.csv')

# %%
# Display the dataframe
olympics_dataset_df
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
# Filter wrestling data
wrestling_df = olympics_dataset_df[olympics_dataset_df['Sport']=='Wrestling'][olympics_dataset_df.Medal.isin(['Gold','Silver','Bronze'])]
# Out:
# c:\users\yh18\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %%
# Display the dataframe
wrestling_df
# Out:
#             ID                              Name Sex   Age  Height  Weight  \
# 186         84              Stephen Anthony Abas   M  26.0   165.0    55.0
# 450        250              Saeid Morad Abdevali   M  26.0   170.0    80.0
# 550        316  Zagalav Abdulbekovich Abdulbekov   M  26.0   160.0    62.0
# 590        339          Namiq Yadulla Abdullayev   M  25.0   167.0    55.0
# 591        339          Namiq Yadulla Abdullayev   M  29.0   167.0    55.0
# ...        ...                               ...  ..   ...     ...     ...
# 270058  135103         Albert Conrad "Al" Zirkel   M  19.0     NaN     NaN
# 270155  135154          Stanka Zlateva Khristova   F  25.0   163.0    72.0
# 270156  135154          Stanka Zlateva Khristova   F  29.0   163.0    72.0
# 270321  135227     dn Zombori (Zanich, Janicsek)   M  25.0     NaN     NaN
# 270322  135227     dn Zombori (Zanich, Janicsek)   M  29.0     NaN     NaN
#
# ...

# %%
# Filter the dataframe columns to select the relevant columns
wrestling_df = wrestling_df[['Team','Year','Medal']]

# %%
# Display the dataframe
wrestling_df
# Out:
#                  Team  Year   Medal
# 186     United States  2004  Silver
# 450              Iran  2016  Bronze
# 550      Soviet Union  1972    Gold
# 590        Azerbaijan  1996  Silver
# 591        Azerbaijan  2000    Gold
# ...               ...   ...     ...
# 270058  United States  1904  Bronze
# 270155       Bulgaria  2008  Silver
# 270156       Bulgaria  2012  Silver
# 270321        Hungary  1932  Silver
# 270322        Hungary  1936    Gold
#
# [1296 rows x 3 columns]

# %%
# Pivot dataframe
wrestling_olympics = wrestling_df.groupby(['Team','Year']).count().reset_index().pivot(index='Team',columns='Year',values='Medal').fillna(0).astype(int).reset_index()

# Looping through the columns and adding the previous column to each column
previous_year = wrestling_olympics.columns[1]
for year in wrestling_olympics.columns[2:]:
    wrestling_olympics[year] = wrestling_olympics[previous_year] + wrestling_olympics[year]
    previous_year = year

# %%
# Display final dataframe
wrestling_olympics
# Out:
# Year                  Team  1896  1904  1906  1908  1912  1920  1924  1928  \
# 0                  Armenia     0     0     0     0     0     0     0     0
# 1                Australia     0     0     0     0     0     0     0     0
# 2                  Austria     0     0     4     4     4     4     4     4
# 3               Azerbaijan     0     0     0     0     0     0     0     0
# 4                  Belarus     0     0     0     0     0     0     0     0
# ..                     ...   ...   ...   ...   ...   ...   ...   ...   ...
# 56    United Arab Republic     0     0     0     0     0     0     0     0
# 57           United States     0    17    17    19    19    25    31    33
# 58              Uzbekistan     0     0     0     0     0     0     0     0
# 59            West Germany     0     0     0     0     0     0     0     0
# 60              Yugoslavia     0     0     0     0     0     0     0     0
#
# ...
